# %%
import pandas as pd

# %%
data = { 
    'name' : ['ajay','Bobby','Sunny'],
    'age' : [23,45,35],
    'city' : ['paris','pune','punjab']
}
print(data)
# Out:
# {'name': ['ajay', 'Bobby', 'Sunny'], 'age': [23, 45, 35], 'city': ['paris', 'pune', 'punjab']}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#     name  age    city
# 0   ajay   23   paris
# 1  Bobby   45    pune
# 2  Sunny   35  punjab

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.columns) ##the column names
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
print(df.shape)  ## rows and columns
# Out:
# (3, 3)

# %%
print(df.dtypes) ## data types for each individual column
# Out:
# name    object
# age      int64
# city    object
# dtype: object

# %%
df.head(2) ## 1st 2 records from first
# Out:
#     name  age   city
# 0   ajay   23  paris
# 1  Bobby   45   pune

# %%
print(df.tail(2)) ## any number of record from the last 
## print use karo ya mat karo print ho jayega
# Out:
#     name  age    city
# 1  Bobby   45    pune
# 2  Sunny   35  punjab

# %%
## how to [take data in pandas dataFrame from your system ##
