# %%
## pandas series , pandas data frame 
## a dataframe is basicllly a two dimensional labelled data structure with columns of patentially 
## different types , similar to excel speadsheet
# pandas libaries function h jo data ko analysis and manipulate karta h

# %%
import pandas as pd

# %%
data = {
    'name' : ['ajay' , 'Bobby', 'sunny'],
    'age' : [24,56,67],
    'city' : ['paris', 'pune','punjab']
}
print(data)
# Out:
# {'name': ['ajay', 'Bobby', 'sunny'], 'age': [24, 56, 67], 'city': ['paris', 'pune', 'punjab']}

# %%
df = pd.DataFrame(data)    
print(df)  ## ya df only likh sakte h
# Out:
#     name  age    city
# 0   ajay   24   paris
# 1  Bobby   56    pune
# 2  sunny   67  punjab

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.columns)  ## columns names
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
print(df.shape)  ## rows and columns
# Out:
# (3, 3)

# %%
print(df.dtypes) ## data types for each individual column
# Out:
# name    object
# age      int64
# city    object
# dtype: object

# %%
print(df.head(2)) # any number of records from the 1st
# Out:
#     name  age   city
# 0   ajay   24  paris
# 1  Bobby   56   pune

# %%
df.tail(2)  # any number of records from the last 
## as well write with print
# Out:
#     name  age    city
# 1  Bobby   56    pune
# 2  sunny   67  punjab

# %%
#3 how to take data in pandas datafame from your system

## D:/---- Folder(data) -- titles.csv
title_data = pd.read_csv("D:/pandas/titles.csv")   ## path / file
print(title_data.head(5))
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
print(title_data.head())
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
## can you do the above dta frame operaations, tell me how many data do we have 
print(title_data.shape)  ## num of rows and columns
# Out:
# (230621, 2)

# %%
## describe all about the statistic like mean , std, min count 25% etc 
print(title_data.describe())  ## describe data
# Out:
#                 year
# count  230621.000000
# mean     1985.695097
# std        29.371587
# min      1894.000000
# 25%      1966.000000
# 50%      1995.000000
# 75%      2011.000000
# max      2026.000000

# %%
print(title_data.info())  ## information f the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230621 entries, 0 to 230620
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   title   230620 non-null  object
#  1   year    230621 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.5+ MB
# None

# %%
data_file = pd.read_csv("D:/pandas/Employee_Building.csv")
print(data_file.describe())
# Out:
#        Years_employed
# count       15.000000
# mean         4.333333
# std          2.919556
# min          0.000000
# 25%          2.000000
# 50%          4.000000
# 75%          6.500000
# max          9.000000

# %%
print(data_file.shape)
# Out:
# (15, 4)

# %%
print(data_file.head(23))  ## 14 only 15 rows here
# Out:
#         Role        Name Building  Years_employed
# 0   Engineer    Becky A.       1e               4
# 1   Engineer      Dan B.       1e               2
# 2   Engineer   Sharon F.       1e               6
# 3   Engineer      Dan M.       1e               4
# 4   Engineer   Malcom S.       1e               1
# 5     Artist    Tylar S.       2w               2
# 6     Artist  Sherman D.       2w               8
# 7     Artist    Jakob J.       2w               6
# 8     Artist   Lillia A.       2w               7
# 9     Artist  Brandon J.       2w               7
# 10   Manager    Scott K.       1e               9
# 11   Manager  Shirlee M.       1e               3
# 12   Manager    Daria O.       2w               6
# 13  Engineer    Yancy I.      NaN               0
# 14    Artist   Oliver P.      NaN               0

# %%
print(data_file.dtypes)
print(data_file.info)
# Out:
# Role              object
# Name              object
# Building          object
# Years_employed     int64
# dtype: object
# <bound method DataFrame.info of         Role        Name Building  Years_employed
# 0   Engineer    Becky A.       1e               4
# 1   Engineer      Dan B.       1e               2
# 2   Engineer   Sharon F.       1e               6
# 3   Engineer      Dan M.       1e               4
# 4   Engineer   Malcom S.       1e               1
# 5     Artist    Tylar S.       2w               2
# 6     Artist  Sherman D.       2w               8
# 7     Artist    Jakob J.       2w               6
# 8     Artist   Lillia A.       2w               7
# 9     Artist  Brandon J.       2w               7
# 10   Manager    Scott K.       1e               9
# 11   Manager  Shirlee M.       1e               3
# 12   Manager    Daria O.       2w               6
# 13  Engineer    Yancy I.      NaN               0
# 14    Artist   Oliver P.      NaN               0>

# %%
## ye pure data me decimal hatane ka kaam karega 
pd.set_option('display.float_format','{:.0f}'.format)

# %%
df['salary'] = [10000, 1200, 1400]  # add column 
df
# Out:
#     name  age    city  salary
# 0   ajay   24   paris   10000
# 1  Bobby   56    pune    1200
# 2  sunny   67  punjab    1400

# %%
data_file
# Out:
#         Role        Name Building  Years_employed
# 0   Engineer    Becky A.       1e               4
# 1   Engineer      Dan B.       1e               2
# 2   Engineer   Sharon F.       1e               6
# 3   Engineer      Dan M.       1e               4
# 4   Engineer   Malcom S.       1e               1
# 5     Artist    Tylar S.       2w               2
# 6     Artist  Sherman D.       2w               8
# 7     Artist    Jakob J.       2w               6
# 8     Artist   Lillia A.       2w               7
# 9     Artist  Brandon J.       2w               7
# 10   Manager    Scott K.       1e               9
# 11   Manager  Shirlee M.       1e               3
# 12   Manager    Daria O.       2w               6
# 13  Engineer    Yancy I.      NaN               0
# 14    Artist   Oliver P.      NaN               0

# %%
data_file.isnull().sum()
# Out:
# Role              0
# Name              0
# Building          2
# Years_employed    0
# dtype: int64
